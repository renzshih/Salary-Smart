# %% [markdown]
# # Simple Batch Processing

# %%
import pandas as pd
import csv

# %%
employees = []
with open("employees.csv") as employees_file:
    reader = csv.DictReader(employees_file)
    [employees.append(row) for row in reader]

# %%
[employee["base pay"] for employee in employees]
# Out:
# ['1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500',
#  '1500']

# %%
# replace numeric strings with numbers
for employee in employees:
    employee["base pay"]=float(employee["base pay"])

# %%
# define functions to compute various pay elements;
# replace with actual figures and formulae

def get_base_pay(employee):
    return employee["base pay"]

def compute_sss(employee):
    return employee["base pay"] * .02

def compute_philhealth(base_pay):
     return employee["base pay"] * .02

def compute_pag_ibig(base_pay):
    return employee["base pay"] * .02

def compute_withholding_tax(base_pay):
    return employee["base pay"] * .10

# %%
# define pay elements per employee

pay_elements = [
    {"name":"Gross Pay","nature":"addition","formula":get_base_pay},
    {"name":"SSS","nature":"addition","formula":compute_sss},
    {"name":"PhilHealth","nature":"addition","formula":compute_philhealth},
    {"name":"Pag-IBIG","nature":"addition","formula":compute_pag_ibig},
    {"name":"Withholding Tax","nature":"addition","formula":compute_withholding_tax},
]

# %%
# generate pay register

# This is just sample output to illustrate batch processing, 
# and you may want to output this to a csv instead of just printing out here.

pay_register = []

# loop through each employee
for employee in employees:
    # loop through each pay element
    for element in pay_elements:
        print("{}-{}:{}".format(employee["last name"],element['name'], element['formula'](employee)))
# Out:
# Duterte-Gross Pay:1500.0
# Duterte-SSS:30.0
# Duterte-PhilHealth:30.0
# Duterte-Pag-IBIG:30.0
# Duterte-Withholding Tax:150.0
# Robredo-Gross Pay:1500.0
# Robredo-SSS:30.0
# Robredo-PhilHealth:30.0
# Robredo-Pag-IBIG:30.0
# Robredo-Withholding Tax:150.0
# Sotto-Gross Pay:1500.0
# Sotto-SSS:30.0
# Sotto-PhilHealth:30.0
# Sotto-Pag-IBIG:30.0
# Sotto-Withholding Tax:150.0
# Cayetano-Gross Pay:1500.0
# Cayetano-SSS:30.0
# Cayetano-PhilHealth:30.0
# Cayetano-Pag-IBIG:30.0
# Cayetano-Withholding Tax:150.0
# Arroyo-Gross Pay:1500.0
# Arroyo-SSS:30.0
# Arroyo-PhilHealth:30.0
# Arroyo-Pag-IBIG:30.0
# Arroyo-Withholding Tax:150.0
# Aquino-Gross Pay:1500.0
# Aquino-SSS:30.0
# Aquino-PhilHealth:30.0
# Aquino-Pag-IBIG:30.0
# Aquino-Withholding Tax:150.0
# Pacquiao-Gross Pay:1500.0
# Pacquiao-SSS:30.0
# Pacquiao-PhilHealth:30.0
# Pacquiao-Pag-IBIG:30.0
# Pacquiao-Withholding Tax:150.0
# Dela Rosa-Gross Pay:1500.0
# Dela Rosa-SSS:30.0
# Dela Rosa-PhilHealth:30.0
# Dela Rosa-Pag-IBIG:30.0
# Dela Rosa-Withholding Tax:150.0
# Villar-Gross Pay:1500.0
# Villar-SSS:30.0
# Villar-PhilHealth:30.0
# Villar-Pag-IBIG:30.0
# Villar-Withholding Tax:150.0
# Poe-Gross Pay:1500.0
# Poe-SSS:30.0
# Poe-PhilHealth:30.0
# Poe-Pag-IBIG:30.0
# Poe-Withholding Tax:150.0
# Go-Gross Pay:1500.0
# Go-SSS:30.0
# Go-PhilHealth:30.0
# Go-Pag-IBIG:30.0
# Go-Withholding Tax:150.0
# Angara-Gross Pay:1500.0
# Angara-SSS:30.0
# Angara-PhilHealth:30.0
# Angara-Pag-IBIG:30.0
# Angara-Withholding Tax:150.0
# Lapid-Gross Pay:1500.0
# Lapid-SSS:30.0
# Lapid-PhilHealth:30.0
# Lapid-Pag-IBIG:30.0
# Lapid-Withholding Tax:150.0
# Marcos-Gross Pay:1500.0
# Marcos-SSS:30.0
# Marcos-PhilHealth:30.0
# Marcos-Pag-IBIG:30.0
# Marcos-Withholding Tax:150.0
# Tolentino-Gross Pay:1500.0
# Tolentino-SSS:30.0
# Tolentino-PhilHealth:30.0
# Tolentino-Pag-IBIG:30.0
# Tolentino-Withholding Tax:150.0
# Pimentel-Gross Pay:1500.0
# Pimentel-SSS:30.0
# Pimentel-PhilHealth:30.0
# Pimentel-Pag-IBIG:30.0
# Pimentel-Withholding Tax:150.0
# Revilla-Gross Pay:1500.0
# Revilla-SSS:30.0
# Revilla-PhilHealth:30.0
# Revilla-Pag-IBIG:30.0
# Revilla-Withholding Tax:150.0
# Binay-Gross Pay:1500.0
# Binay-SSS:30.0
# Binay-PhilHealth:30.0
# Binay-Pag-IBIG:30.0
# Binay-Withholding Tax:150.0
# Cayetano-Gross Pay:1500.0
# Cayetano-SSS:30.0
# Cayetano-PhilHealth:30.0
# Cayetano-Pag-IBIG:30.0
# Cayetano-Withholding Tax:150.0
# Estrada-Gross Pay:1500.0
# Estrada-SSS:30.0
# Estrada-PhilHealth:30.0
# Estrada-Pag-IBIG:30.0
# Estrada-Withholding Tax:150.0
# Roxas-Gross Pay:1500.0
# Roxas-SSS:30.0
# Roxas-PhilHealth:30.0
# Roxas-Pag-IBIG:30.0
# Roxas-Withholding Tax:150.0
# Manicad-Gross Pay:1500.0
# Manicad-SSS:30.0
# Manicad-PhilHealth:30.0
# Manicad-Pag-IBIG:30.0
# Manicad-Withholding Tax:150.0
# Ejercito-Gross Pay:1500.0
# Ejercito-SSS:30.0
# Ejercito-PhilHealth:30.0
# Ejercito-Pag-IBIG:30.0
# Ejercito-Withholding Tax:150.0

# %%
# Generate pay slips

# This is just sample output to illustrate batch processing.
# You may want to write each payslip to an HTML file for proper formatting.
# In between, you may want to inject headers for Additions and substractions (with subtotals).

# loop through each employee
for employee in employees:
    print("---------------------------")
    print("{} {}".format(employee["first name"],employee["last name"]))
    # loop through each pay element
    for element in pay_elements:
        print("{}:{}".format(element['name'], element['formula'](employee)))
# Out:
# ---------------------------
# Rodrigo Duterte
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Leni Robredo
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Tito Sotto
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Peter Cayetano
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Gloria Arroyo
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Bam Aquino
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Manny Pacquiao
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Bato Dela Rosa
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Cynthia Villar
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Grace Poe
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Bong Go
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Sonny Angara
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Lito Lapid
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Imee Marcos
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Francis Tolentino
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Koko Pimentel
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Bong Revilla
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Nancy Binay
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Pia Cayetano
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Jinggoy Estrada
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Mar Roxas
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# Jiggy Manicad
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0
# ---------------------------
# JV Ejercito
# Gross Pay:1500.0
# SSS:30.0
# PhilHealth:30.0
# Pag-IBIG:30.0
# Withholding Tax:150.0

# %% [markdown]
# #### Additional Notes:
#
# Instead of reading directly from csv, you may want to opt for the use of Pandas and loop for each row.
#
# Pandas will allow easy merging/joining with other datasets including loans/advances and timekeeping (overtime/absences/tardiness).
#
# Best to join/merge by employee ids instead of first names and last names (to avoid collision).
